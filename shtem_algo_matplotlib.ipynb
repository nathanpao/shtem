# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import os
# %matplotlib inline

# %%
a = np.linspace(0, 4*np.pi, 1000)
b = np.sin(a)

# %%
fig, ax = plt.subplots()
ax.plot(a, b)
fig.show()
# Out:
# C:\Users\natha\AppData\Local\Temp\ipykernel_82728\2543874770.py:3: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %%
df = pd.read_csv(r"C:\Users\natha\Downloads\S&Ptestabbrv\allstocks_20190325\table_aapl.csv", header=None)

# %%
df.columns = ['Date', 'Time', 'Open', 'High', 'Low', 'Close', 'Volume', 'X', 'Y', 'Z']
df
# Out:
#          Date  Time     Open     High      Low    Close     Volume  X  Y  Z
# 0    20190325   700  46.7357  46.7971  46.7357  46.7971  21878.100  4  0  0
# 1    20190325   701  46.7775  46.7996  46.7652  46.7775  17726.300  4  0  0
# 2    20190325   702  46.7971  46.7996  46.7529  46.7529  13277.400  4  0  0
# 3    20190325   703  46.7406  46.7406  46.7332  46.7332   3256.270  4  0  0
# 4    20190325   704  46.7406  46.7406  46.7332  46.7332   3524.910  4  0  0
# ..        ...   ...      ...      ...      ...      ...        ... .. .. ..
# 751  20190325  1955  46.3967  46.4654  46.3967  46.4654   4656.460  4  0  0
# 752  20190325  1956  46.4335  46.4335  46.3721  46.4212   2006.680  4  0  0
# 753  20190325  1957  46.4188  46.4212  46.4188  46.4212    671.606  4  0  0
# 754  20190325  1958  46.4384  46.4384  46.4212  46.4212   2796.320  4  0  0
# 755  20190325  1959  46.4335  46.4728  46.3721  46.4089  22907.900  4  0  0
#
# [756 rows x 10 columns]

# %%
x = df.Volume.values
y = df.Close.values
fig, ax = plt.subplots()
ax.plot(x, y)
fig.show()
# Out:
# C:\Users\natha\AppData\Local\Temp\ipykernel_82728\787502524.py:5: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %%
x = np.random.uniform(0, 1, 100)
y = np.random.uniform(0, 1, 100)
fig, ax = plt.subplots()
ax.scatter(x, y)

# %%
x = np.random.uniform(0, 1, 10)
y = np.random.uniform(0, 1, 10)
fig, ax = plt.subplots()
ax.bar(x, y)
# Out:
# <BarContainer object of 10 artists>

# %%
z = np.random.uniform(0, 1, (8, 8))
fig, ax = plt.subplots()
ax.imshow(z)

# %%
z = np.random.uniform(0, 1, (8, 8))
fig, ax = plt.subplots()
ax.contourf(z)

# %%
z = np.random.uniform(0, 1, 4)
fig, ax = plt.subplots()
ax.pie(z)
# Out:
# ([<matplotlib.patches.Wedge at 0x2c31f1220d0>,
# ...
#  [Text(0.5867604870478651, 0.9304365270341401, ''),
#   Text(-1.082052718655177, 0.1978936938129686, ''),
#   Text(-0.06522390928627547, -1.0980645890189775, ''),
#   Text(0.99472104362488, -0.46960626632300156, '')])

# %%
z = np.random.uniform(0, 1, 100)
fig, ax = plt.subplots()
ax.hist(z)
# Out:
# (array([14.,  8.,  9., 11., 10.,  7.,  5.,  6., 20., 10.]),
#  array([5.66877092e-04, 1.00134109e-01, 1.99701342e-01, 2.99268574e-01,
#         3.98835806e-01, 4.98403039e-01, 5.97970271e-01, 6.97537503e-01,
#         7.97104736e-01, 8.96671968e-01, 9.96239200e-01]),
#  <BarContainer object of 10 artists>)

# %%
z = np.random.uniform(0, 1, (100, 3))
fig, ax = plt.subplots()
ax.boxplot(z)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x2c31f1dfe20>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x2c31f1ef400>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x2c31f1dfb50>,
# ...
#  'medians': [<matplotlib.lines.Line2D at 0x2c31f1ef9a0>,
# ...
#  'fliers': [<matplotlib.lines.Line2D at 0x2c31f1efc70>,
# ...
#  'means': []}

# %%
x = np.linspace(0, 10, 100)
y = np.sin(x)
fig, ax = plt.subplots()
ax.plot(x, y, color = "red", linestyle = "--", linewidth = 5, marker = "p")

# %%
x = np.linspace(0, 10, 100)
y1, y2 = np.sin(x), np.cos(x)
fig, ax = plt.subplots()
ax.plot(x, y1, x, y2)
ax.set_title("Math")
ax.set_ylabel('values')
ax.set_xlabel('time')
# Out:
# Text(0.5, 0, 'time')

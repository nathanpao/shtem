# %%
import matplotlib.pyplot as plt
import numpy as np

Grades = ['11th', '12th', 'Freshman', 'Sophomore']
StudentsPerGrade = [4, 52, 8, 3]

EvenDistance = np.arange(len(Grades))

plt.bar(EvenDistance, StudentsPerGrade, width = 0.75, color = ['orange', 'pink', 'blue', 'red'], edgecolor = 'black')
plt.xticks(EvenDistance, Grades)
plt.xlabel("Grades")
plt.ylabel("Number of Students")
plt.title("Grade Distribution")

plt.show()

# %%
Games = ["#1", "#2", "#3", "#4", "#5"]
Warriors = [108, 107, 100, 107, 104]
Celtics = [120, 88, 116, 97, 94]

distance = np.arange(len(Games))
plt.bar(distance - 0.2, Warriors, 0.4, label = "Warriors", color = 'blue')
plt.bar(distance + 0.2, Celtics, 0.4, label = "Celtics", color = 'green' )
plt.xticks(distance, Games)
plt.xlabel("Game Number")
plt.ylabel("Points Scored")
plt.legend()

plt.show()

# %%
plt.plot(Games, Warriors)
plt.plot(Games, Celtics)
plt.title("NBA Finals Points")
plt.show()

plt.plot(Games, Warriors, color = 'blue', marker = 'o', label = "Warriors")
plt.plot(Games, Celtics, color = 'green', marker = '>', label = "Celtics")
plt.grid(True)
plt.legend()
plt.xlabel("Game Number", fontsize = 14)
plt.ylabel("Points Scored", fontsize = 14)
plt.title("NBA Ginals Points", fontsize = 20)
plt.show()

# %%
values = [7, 10, 48, 20, 17, 8, 42, 23, 71, 42, 52, 28, 42, 60, 26, 56, 22, 20, 7, 99, 0, 69, 11, 43, 26, 12, 12, 99, 48, 
          22, 9, 97, 36, 47, 79, 13, 16, 60, 23.75, 76, 57, 73, 15, 14, 25, 77, 20, 70, 23, 20, 76, 77, 42, 25, 5, 19, 3, 
          71, 52, 98, 8, 27, 68, 76, 48, 8, 55]
plt.boxplot(values)
plt.show()

plt.violinplot(values)
plt.show()

# %%
astro_labels = ['Aries', 'Taurus', 'Gemini', 'Cancer', 'Leo', 'Virgo', 'Libra', 'Scorpio', 'Sagittarius', 'Capricorn', 'Aquarius', 'Pisces']
students_astro = [7, 4, 5, 6, 6, 5, 6, 4, 10, 4, 5, 5]
students_oneDirection = [3, 3, 2, 2, 1, 2, 4, 1, 3, 1, 2, 3]

d = np.arange(len(astro_labels))

#fig = plt.figure()
#ax = fig.add_subplot()

fig, ax = plt.subplots()

ax.plot(astro_labels, students_oneDirection, color = 'black')
ax.set_ylabel("Students Who Know 1D")
ax.set_ylim(0, 5)
ax.legend(["Knows 1D"], loc = "upper left")
ax.set_xticklabels(astro_labels, rotation = 45, fontsize = 8)

ax2 = ax.twinx()
ax2.bar(d, students_astro, width = 0.5, color = 'orange', alpha = 0.5)
ax2.set_ylim(0, 12)
ax2.legend(["Num Students"], loc = "upper right")
ax2.set_ylabel("Students per Astro Sign")
ax2.grid(False)
plt.show()
# Out:
# C:\Users\natha\AppData\Local\Temp\ipykernel_3456\3960484238.py:16: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(astro_labels, rotation = 45, fontsize = 8)

# %%
color = 'red', 'pink', 'orange', 'yellow', 'green', 'cyan', 'blue', 'purple', 'violet' , 'white', 'grey', 'brown'
fix, ax = plt.subplots()
ax.pie(students_astro, colors = color, labels = astro_labels, startangle = 90, autopct = '%1.1f%%', textprops = {'color' : "black"})
plt.show()
fig = plt.gcf()
